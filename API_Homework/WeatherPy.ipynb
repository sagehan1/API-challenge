# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name

    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 616

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = f"http://api.openweathermap.org/data/2.5/weather?appid={weather_api_key}&units=metric&q="

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{url}{city}"


    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = city_weather['dt']

        # Append the City information into city_data list
        city_data.append({"City": city,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

    # pause to avoid rate limiting
    time.sleep(1)

# Indicate that Data Loading is complete
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | taiohae
# City not found. Skipping...
# Processing Record 2 of Set 1 | adamstown
# Processing Record 3 of Set 1 | invercargill
# Processing Record 4 of Set 1 | port-aux-francais
# Processing Record 5 of Set 1 | waitangi
# Processing Record 6 of Set 1 | isafjordur
# Processing Record 7 of Set 1 | margaret river
# Processing Record 8 of Set 1 | afaahiti
# Processing Record 9 of Set 1 | albany
# Processing Record 10 of Set 1 | selfoss
# Processing Record 11 of Set 1 | wantirna
# Processing Record 12 of Set 1 | vadso
# Processing Record 13 of Set 1 | vilyuchinsk
# Processing Record 14 of Set 1 | puerto natales
# Processing Record 15 of Set 1 | miri
# Processing Record 16 of Set 1 | edinburgh of the seven seas
# Processing Record 17 of Set 1 | ust-nera
# Processing Record 18 of Set 1 | portland
# Processing Record 19 of Set 1 | vingt cinq
# City not found. Skipping...
# Processing Record 20 of Set 1 | badger
# Processing Record 21 of Set 1 | melekeok village
# Processing Record 22 of Set 1 | ronne
# Processing Record 23 of Set 1 | melekhovo
# Processing Record 24 of Set 1 | khalis
# Processing Record 25 of Set 1 | pauini
# Processing Record 26 of Set 1 | ayr
# Processing Record 27 of Set 1 | chonchi
# Processing Record 28 of Set 1 | faya-largeau
# Processing Record 29 of Set 1 | bhimunipatnam
# Processing Record 30 of Set 1 | nova vodolaha
# Processing Record 31 of Set 1 | bonthe
# Processing Record 32 of Set 1 | aguada de pasajeros
# Processing Record 33 of Set 1 | ilulissat
# Processing Record 34 of Set 1 | papao
# Processing Record 35 of Set 1 | ushuaia
# Processing Record 36 of Set 1 | lompoc
# Processing Record 37 of Set 1 | thunder bay
# Processing Record 38 of Set 1 | ribeira grande
# Processing Record 39 of Set 1 | gusinoozyorsk
# Processing Record 40 of Set 1 | visby
# Processing Record 41 of Set 1 | egilsstadir
# Processing Record 42 of Set 1 | sitka
# Processing Record 43 of Set 1 | mahina
# Processing Record 44 of Set 1 | kailua-kona
# Processing Record 45 of Set 1 | hirekerur
# Processing Record 46 of Set 1 | bethel
# Processing Record 47 of Set 1 | whitecourt
# Processing Record 48 of Set 1 | talnakh
# Processing Record 49 of Set 1 | taiynsha
# Processing Record 50 of Set 1 | roghun
# Processing Record 0 of Set 2 | levuka
# Processing Record 1 of Set 2 | vernon
# Processing Record 2 of Set 2 | tobi village
# City not found. Skipping...
# Processing Record 3 of Set 2 | hermanus
# Processing Record 4 of Set 2 | lichtenburg
# Processing Record 5 of Set 2 | san antonio de pale
# Processing Record 6 of Set 2 | puerto ayora
# Processing Record 7 of Set 2 | mimizan
# Processing Record 8 of Set 2 | varzea da palma
# Processing Record 9 of Set 2 | bileca
# Processing Record 10 of Set 2 | port macquarie
# Processing Record 11 of Set 2 | dryden
# Processing Record 12 of Set 2 | punta arenas
# Processing Record 13 of Set 2 | hobyo
# Processing Record 14 of Set 2 | hasaki
# Processing Record 15 of Set 2 | port elizabeth
# Processing Record 16 of Set 2 | grytviken
# Processing Record 17 of Set 2 | kokoda
# Processing Record 18 of Set 2 | soio
# Processing Record 19 of Set 2 | mount vernon
# Processing Record 20 of Set 2 | tindouf
# Processing Record 21 of Set 2 | simrishamn
# Processing Record 22 of Set 2 | queenstown
# Processing Record 23 of Set 2 | yulinshi
# Processing Record 24 of Set 2 | igaci
# Processing Record 25 of Set 2 | conceicao do araguaia
# Processing Record 26 of Set 2 | tomatlan
# Processing Record 27 of Set 2 | nova sintra
# Processing Record 28 of Set 2 | port mathurin
# Processing Record 29 of Set 2 | hoemul-li
# Processing Record 30 of Set 2 | utrik
# Processing Record 31 of Set 2 | yellowknife
# Processing Record 32 of Set 2 | vilhena
# Processing Record 33 of Set 2 | thisted
# Processing Record 34 of Set 2 | pinos
# Processing Record 35 of Set 2 | west island
# Processing Record 36 of Set 2 | hadibu
# Processing Record 37 of Set 2 | weno
# Processing Record 38 of Set 2 | guerrero negro
# Processing Record 39 of Set 2 | metlili chaamba
# Processing Record 40 of Set 2 | nurlat
# Processing Record 41 of Set 2 | kodiak
# Processing Record 42 of Set 2 | azna
# Processing Record 43 of Set 2 | georgetown
# Processing Record 44 of Set 2 | east porterville
# Processing Record 45 of Set 2 | forster
# Processing Record 46 of Set 2 | thompson
# Processing Record 47 of Set 2 | belyy yar
# Processing Record 48 of Set 2 | ta`u
# Processing Record 49 of Set 2 | fale old settlement
# Processing Record 0 of Set 3 | coahuayana de hidalgo
# Processing Record 1 of Set 3 | papatowai
# Processing Record 2 of Set 3 | vorgashor
# Processing Record 3 of Set 3 | whitehorse
# Processing Record 4 of Set 3 | fort bragg
# Processing Record 5 of Set 3 | al mindak
# Processing Record 6 of Set 3 | sant feliu de guixols
# Processing Record 7 of Set 3 | hailey
# Processing Record 8 of Set 3 | bilibino
# Processing Record 9 of Set 3 | port lincoln
# Processing Record 10 of Set 3 | pacasmayo
# Processing Record 11 of Set 3 | martapura
# Processing Record 12 of Set 3 | blackmans bay
# Processing Record 13 of Set 3 | kitwe
# Processing Record 14 of Set 3 | betio village
# Processing Record 15 of Set 3 | nuuk
# Processing Record 16 of Set 3 | carnarvon
# Processing Record 17 of Set 3 | nema
# Processing Record 18 of Set 3 | staroaleyskoye
# Processing Record 19 of Set 3 | bikenibeu village
# Processing Record 20 of Set 3 | turpan
# Processing Record 21 of Set 3 | takamaka
# City not found. Skipping...
# Processing Record 22 of Set 3 | santa cruz das palmeiras
# Processing Record 23 of Set 3 | bubaque
# Processing Record 24 of Set 3 | rongelap
# Processing Record 25 of Set 3 | kuloy
# Processing Record 26 of Set 3 | freetown
# Processing Record 27 of Set 3 | lebu
# Processing Record 28 of Set 3 | axim
# Processing Record 29 of Set 3 | longyearbyen
# Processing Record 30 of Set 3 | fort st. john
# Processing Record 31 of Set 3 | iqaluit
# Processing Record 32 of Set 3 | rio gallegos
# Processing Record 33 of Set 3 | sarangani
# Processing Record 34 of Set 3 | san patricio
# Processing Record 35 of Set 3 | boise
# Processing Record 36 of Set 3 | newman
# Processing Record 37 of Set 3 | manado
# Processing Record 38 of Set 3 | wailua homesteads
# Processing Record 39 of Set 3 | al bardiyah
# Processing Record 40 of Set 3 | touros
# Processing Record 41 of Set 3 | zuni pueblo
# Processing Record 42 of Set 3 | jamestown
# Processing Record 43 of Set 3 | kilmore
# Processing Record 44 of Set 3 | banfora
# Processing Record 45 of Set 3 | gadzhiyevo
# Processing Record 46 of Set 3 | aykhal
# Processing Record 47 of Set 3 | port saint john's
# Processing Record 48 of Set 3 | lihue
# Processing Record 49 of Set 3 | musay'id
# City not found. Skipping...
# Processing Record 0 of Set 4 | kapenguria
# Processing Record 1 of Set 4 | avarua
# Processing Record 2 of Set 4 | malango
# Processing Record 3 of Set 4 | atafu village
# Processing Record 4 of Set 4 | la sarre
# Processing Record 5 of Set 4 | temiskaming shores
# Processing Record 6 of Set 4 | bamboo flat
# Processing Record 7 of Set 4 | morehead city
# Processing Record 8 of Set 4 | constantia
# Processing Record 9 of Set 4 | qingyuan
# Processing Record 10 of Set 4 | lekeitio
# Processing Record 11 of Set 4 | qamdo
# Processing Record 12 of Set 4 | beitbridge
# Processing Record 13 of Set 4 | sinabang
# Processing Record 14 of Set 4 | tiksi
# Processing Record 15 of Set 4 | bulnes
# Processing Record 16 of Set 4 | hammerfest
# Processing Record 17 of Set 4 | grantsville
# Processing Record 18 of Set 4 | geneina
# Processing Record 19 of Set 4 | bushland beach
# City not found. Skipping...
# Processing Record 20 of Set 4 | iskateley
# Processing Record 21 of Set 4 | iwon-up
# Processing Record 22 of Set 4 | okha
# Processing Record 23 of Set 4 | qaqortoq
# Processing Record 24 of Set 4 | hovd
# Processing Record 25 of Set 4 | la mira
# Processing Record 26 of Set 4 | midvagur
# Processing Record 27 of Set 4 | shimoda
# Processing Record 28 of Set 4 | kingston
# Processing Record 29 of Set 4 | ouellah
# City not found. Skipping...
# Processing Record 30 of Set 4 | magadan
# Processing Record 31 of Set 4 | vila franca do campo
# Processing Record 32 of Set 4 | laayoune plage
# City not found. Skipping...
# Processing Record 33 of Set 4 | klyuchi
# Processing Record 34 of Set 4 | rabaul
# Processing Record 35 of Set 4 | ranau
# Processing Record 36 of Set 4 | concepcion
# Processing Record 37 of Set 4 | hamilton
# Processing Record 38 of Set 4 | boundiali
# Processing Record 39 of Set 4 | tofol
# Processing Record 40 of Set 4 | langxiang
# Processing Record 41 of Set 4 | westport
# Processing Record 42 of Set 4 | figuig (centre)
# Processing Record 43 of Set 4 | tolanaro
# Processing Record 44 of Set 4 | nova vicosa
# Processing Record 45 of Set 4 | pangody
# Processing Record 46 of Set 4 | cabo san lucas
# Processing Record 47 of Set 4 | minas de marcona
# Processing Record 48 of Set 4 | colonia
# Processing Record 49 of Set 4 | korhogo
# Processing Record 0 of Set 5 | mbuji-mayi
# Processing Record 1 of Set 5 | taltal
# Processing Record 2 of Set 5 | haiku-pauwela
# Processing Record 3 of Set 5 | illapel
# Processing Record 4 of Set 5 | coos bay
# Processing Record 5 of Set 5 | las heras
# Processing Record 6 of Set 5 | ivins
# Processing Record 7 of Set 5 | wynyard
# Processing Record 8 of Set 5 | shingu
# Processing Record 9 of Set 5 | saint-philippe
# Processing Record 10 of Set 5 | dar chioukh
# Processing Record 11 of Set 5 | fria
# Processing Record 12 of Set 5 | arica
# Processing Record 13 of Set 5 | santana
# Processing Record 14 of Set 5 | zeya
# Processing Record 15 of Set 5 | diamantina
# Processing Record 16 of Set 5 | lishui
# Processing Record 17 of Set 5 | olyokminsk
# Processing Record 18 of Set 5 | sheki
# Processing Record 19 of Set 5 | hawaiian paradise park
# Processing Record 20 of Set 5 | udachny
# Processing Record 21 of Set 5 | dhamar
# Processing Record 22 of Set 5 | padam
# City not found. Skipping...
# Processing Record 23 of Set 5 | bredasdorp
# Processing Record 24 of Set 5 | kudahuvadhoo
# Processing Record 25 of Set 5 | arraial do cabo
# Processing Record 26 of Set 5 | vail
# Processing Record 27 of Set 5 | eyl
# Processing Record 28 of Set 5 | padang
# Processing Record 29 of Set 5 | urangan
# Processing Record 30 of Set 5 | sengkang
# Processing Record 31 of Set 5 | saint-pierre
# Processing Record 32 of Set 5 | college
# Processing Record 33 of Set 5 | cidreira
# Processing Record 34 of Set 5 | sumbawa besar
# Processing Record 35 of Set 5 | sao joao da barra
# Processing Record 36 of Set 5 | abepura
# Processing Record 37 of Set 5 | keflavik
# Processing Record 38 of Set 5 | gewane
# Processing Record 39 of Set 5 | praia
# Processing Record 40 of Set 5 | enewetak
# Processing Record 41 of Set 5 | nikol'sk
# Processing Record 42 of Set 5 | porto novo
# Processing Record 43 of Set 5 | acapulco de juarez
# Processing Record 44 of Set 5 | wiltz
# Processing Record 45 of Set 5 | byron bay
# Processing Record 46 of Set 5 | guiuan
# Processing Record 47 of Set 5 | severo-yeniseyskiy
# Processing Record 48 of Set 5 | kolpny
# Processing Record 49 of Set 5 | east london
# Processing Record 0 of Set 6 | tamanrasset
# Processing Record 1 of Set 6 | tuy hoa
# Processing Record 2 of Set 6 | kaiyuan
# Processing Record 3 of Set 6 | petropavlovsk-kamchatsky
# Processing Record 4 of Set 6 | san luis de la loma
# Processing Record 5 of Set 6 | la'ie
# Processing Record 6 of Set 6 | mar del plata
# Processing Record 7 of Set 6 | new norfolk
# Processing Record 8 of Set 6 | las lomitas
# Processing Record 9 of Set 6 | xining
# Processing Record 10 of Set 6 | stanley
# Processing Record 11 of Set 6 | kurumkan
# Processing Record 12 of Set 6 | mahajanga
# Processing Record 13 of Set 6 | kavaratti
# Processing Record 14 of Set 6 | glendive
# Processing Record 15 of Set 6 | balykshi
# Processing Record 16 of Set 6 | olonkinbyen
# Processing Record 17 of Set 6 | sur
# Processing Record 18 of Set 6 | mount isa
# Processing Record 19 of Set 6 | maralal
# Processing Record 20 of Set 6 | mugia
# Processing Record 21 of Set 6 | harnai
# Processing Record 22 of Set 6 | mutuali
# Processing Record 23 of Set 6 | mildura
# Processing Record 24 of Set 6 | bosansko grahovo
# Processing Record 25 of Set 6 | yuzhno-kurilsk
# Processing Record 26 of Set 6 | berezovyy
# Processing Record 27 of Set 6 | labytnangi
# Processing Record 28 of Set 6 | vila velha
# Processing Record 29 of Set 6 | belluru
# Processing Record 30 of Set 6 | yekaterinoslavka
# Processing Record 31 of Set 6 | kupang
# Processing Record 32 of Set 6 | kadugli
# Processing Record 33 of Set 6 | villa emilio carranza
# Processing Record 34 of Set 6 | lucea
# Processing Record 35 of Set 6 | tromso
# Processing Record 36 of Set 6 | dudinka
# Processing Record 37 of Set 6 | puerto san carlos
# City not found. Skipping...
# Processing Record 38 of Set 6 | seria
# Processing Record 39 of Set 6 | la passe
# Processing Record 40 of Set 6 | hithadhoo
# Processing Record 41 of Set 6 | codrington
# Processing Record 42 of Set 6 | fasa
# Processing Record 43 of Set 6 | clodomira
# Processing Record 44 of Set 6 | boa vista
# Processing Record 45 of Set 6 | nola
# Processing Record 46 of Set 6 | makokou
# Processing Record 47 of Set 6 | panaba
# Processing Record 48 of Set 6 | anadyr
# Processing Record 49 of Set 6 | feijo
# Processing Record 0 of Set 7 | pio xii
# Processing Record 1 of Set 7 | jaru
# Processing Record 2 of Set 7 | pinotepa nacional
# Processing Record 3 of Set 7 | lerwick
# Processing Record 4 of Set 7 | farasan
# Processing Record 5 of Set 7 | madison heights
# Processing Record 6 of Set 7 | lazarevskoye
# Processing Record 7 of Set 7 | teknaf
# Processing Record 8 of Set 7 | iquitos
# Processing Record 9 of Set 7 | rabigh
# Processing Record 10 of Set 7 | burao
# Processing Record 11 of Set 7 | fortuna
# Processing Record 12 of Set 7 | inhambane
# Processing Record 13 of Set 7 | brookings
# Processing Record 14 of Set 7 | saint-joseph
# Processing Record 15 of Set 7 | kihoku-cho
# Processing Record 16 of Set 7 | cuenca
# Processing Record 17 of Set 7 | yeonil
# Processing Record 18 of Set 7 | burutu
# Processing Record 19 of Set 7 | palmas
# Processing Record 20 of Set 7 | bansi
# Processing Record 21 of Set 7 | kangundo
# Processing Record 22 of Set 7 | kapa'a
# Processing Record 23 of Set 7 | harper
# Processing Record 24 of Set 7 | nar'yan-mar
# Processing Record 25 of Set 7 | isla mujeres
# Processing Record 26 of Set 7 | beardstown
# Processing Record 27 of Set 7 | arbus
# Processing Record 28 of Set 7 | hecun
# Processing Record 29 of Set 7 | dalandzadgad
# Processing Record 30 of Set 7 | uturoa
# Processing Record 31 of Set 7 | alice springs
# Processing Record 32 of Set 7 | chibougamau
# Processing Record 33 of Set 7 | aasiaat
# Processing Record 34 of Set 7 | ola
# Processing Record 35 of Set 7 | victoria point
# Processing Record 36 of Set 7 | sonsorol village
# City not found. Skipping...
# Processing Record 37 of Set 7 | jayapura
# Processing Record 38 of Set 7 | lazaro cardenas
# Processing Record 39 of Set 7 | west plains
# Processing Record 40 of Set 7 | floro
# Processing Record 41 of Set 7 | lubao
# Processing Record 42 of Set 7 | pelabuhanratu
# Processing Record 43 of Set 7 | puerto colombia
# Processing Record 44 of Set 7 | taguatinga
# Processing Record 45 of Set 7 | kharan
# Processing Record 46 of Set 7 | camocim
# Processing Record 47 of Set 7 | smithers
# Processing Record 48 of Set 7 | ilula
# Processing Record 49 of Set 7 | bintulu
# Processing Record 0 of Set 8 | usinsk
# Processing Record 1 of Set 8 | laojunmiao
# Processing Record 2 of Set 8 | da nang
# Processing Record 3 of Set 8 | bathsheba
# Processing Record 4 of Set 8 | kaohsiung
# Processing Record 5 of Set 8 | upper grand lagoon
# Processing Record 6 of Set 8 | muisne
# Processing Record 7 of Set 8 | mana
# Processing Record 8 of Set 8 | carutapera
# Processing Record 9 of Set 8 | douglas
# Processing Record 10 of Set 8 | nemuro
# Processing Record 11 of Set 8 | kataragama
# City not found. Skipping...
# Processing Record 12 of Set 8 | penhalonga
# Processing Record 13 of Set 8 | pekan
# Processing Record 14 of Set 8 | salaga
# Processing Record 15 of Set 8 | chernyshevskiy
# Processing Record 16 of Set 8 | mocimboa
# Processing Record 17 of Set 8 | cairns city
# City not found. Skipping...
# Processing Record 18 of Set 8 | ayaguz
# City not found. Skipping...
# Processing Record 19 of Set 8 | lodja
# Processing Record 20 of Set 8 | paita
# Processing Record 21 of Set 8 | hotan
# Processing Record 22 of Set 8 | atar
# Processing Record 23 of Set 8 | illizi
# Processing Record 24 of Set 8 | fiambala
# Processing Record 25 of Set 8 | pisco
# Processing Record 26 of Set 8 | parabel'
# Processing Record 27 of Set 8 | kongsvinger
# Processing Record 28 of Set 8 | fumel
# Processing Record 29 of Set 8 | howard springs
# Processing Record 30 of Set 8 | port alfred
# Processing Record 31 of Set 8 | sandnessjoen
# Processing Record 32 of Set 8 | ascension
# Processing Record 33 of Set 8 | dunedin
# Processing Record 34 of Set 8 | jiayuguan
# Processing Record 35 of Set 8 | alpine
# Processing Record 36 of Set 8 | cranbrook
# Processing Record 37 of Set 8 | sungai penuh
# Processing Record 38 of Set 8 | cockburn town
# Processing Record 39 of Set 8 | wervik
# Processing Record 40 of Set 8 | ulaangom
# Processing Record 41 of Set 8 | karaj
# Processing Record 42 of Set 8 | manaure
# Processing Record 43 of Set 8 | bayawan
# Processing Record 44 of Set 8 | g'uzor
# Processing Record 45 of Set 8 | havre
# Processing Record 46 of Set 8 | fuvahmulah
# City not found. Skipping...
# Processing Record 47 of Set 8 | chandler
# Processing Record 48 of Set 8 | jianshui
# Processing Record 49 of Set 8 | kapuskasing
# Processing Record 0 of Set 9 | saint croix
# Processing Record 1 of Set 9 | puerto baquerizo moreno
# Processing Record 2 of Set 9 | san pedro
# Processing Record 3 of Set 9 | gaspe
# Processing Record 4 of Set 9 | latina
# Processing Record 5 of Set 9 | tidjikja
# Processing Record 6 of Set 9 | tekkali
# Processing Record 7 of Set 9 | bukittinggi
# Processing Record 8 of Set 9 | quellon
# Processing Record 9 of Set 9 | sipalay
# Processing Record 10 of Set 9 | stung treng
# Processing Record 11 of Set 9 | darwin
# Processing Record 12 of Set 9 | hegang
# Processing Record 13 of Set 9 | tsiombe
# Processing Record 14 of Set 9 | ocean pointe
# City not found. Skipping...
# Processing Record 15 of Set 9 | solnechnyy
# Processing Record 16 of Set 9 | saipan
# Processing Record 17 of Set 9 | penzance
# Processing Record 18 of Set 9 | mukah
# City not found. Skipping...
# Processing Record 19 of Set 9 | northam
# Processing Record 20 of Set 9 | alofi
# Processing Record 21 of Set 9 | rio san juan
# Processing Record 22 of Set 9 | aykol
# Processing Record 23 of Set 9 | suva
# Processing Record 24 of Set 9 | tranovaho
# City not found. Skipping...
# Processing Record 25 of Set 9 | sompeta
# Processing Record 26 of Set 9 | igrim
# Processing Record 27 of Set 9 | isangel
# Processing Record 28 of Set 9 | mount gambier
# Processing Record 29 of Set 9 | flying fish cove
# Processing Record 30 of Set 9 | gordonvale
# Processing Record 31 of Set 9 | phillip island
# Processing Record 32 of Set 9 | pudozh
# Processing Record 33 of Set 9 | ravenna
# Processing Record 34 of Set 9 | bridgewater
# Processing Record 35 of Set 9 | amarante do maranhao
# Processing Record 36 of Set 9 | afif
# Processing Record 37 of Set 9 | lata
# Processing Record 38 of Set 9 | ondjiva
# Processing Record 39 of Set 9 | antsiranana
# Processing Record 40 of Set 9 | novaya igirma
# Processing Record 41 of Set 9 | swainsboro
# Processing Record 42 of Set 9 | lakatoro
# Processing Record 43 of Set 9 | mukalla
# Processing Record 44 of Set 9 | baoro
# Processing Record 45 of Set 9 | carauari
# Processing Record 46 of Set 9 | brakel
# Processing Record 47 of Set 9 | san jose village
# City not found. Skipping...
# Processing Record 48 of Set 9 | tazovsky
# Processing Record 49 of Set 9 | panna
# Processing Record 0 of Set 10 | galveston
# Processing Record 1 of Set 10 | rath
# Processing Record 2 of Set 10 | naze
# Processing Record 3 of Set 10 | qom
# Processing Record 4 of Set 10 | calabozo
# Processing Record 5 of Set 10 | ataq
# Processing Record 6 of Set 10 | villa dolores
# Processing Record 7 of Set 10 | taulaga
# Processing Record 8 of Set 10 | burang
# Processing Record 9 of Set 10 | luchow
# Processing Record 10 of Set 10 | aldama
# Processing Record 11 of Set 10 | christchurch
# Processing Record 12 of Set 10 | belmonte
# Processing Record 13 of Set 10 | tumayr
# Processing Record 14 of Set 10 | nassogne
# Processing Record 15 of Set 10 | kolobrzeg
# Processing Record 16 of Set 10 | saratamata
# City not found. Skipping...
# Processing Record 17 of Set 10 | nadym
# Processing Record 18 of Set 10 | yaren
# Processing Record 19 of Set 10 | tanrake village
# City not found. Skipping...
# Processing Record 20 of Set 10 | grand-bourg
# Processing Record 21 of Set 10 | santa ana
# Processing Record 22 of Set 10 | mejit
# Processing Record 23 of Set 10 | happy valley-goose bay
# Processing Record 24 of Set 10 | amalapuram
# Processing Record 25 of Set 10 | birkenau
# Processing Record 26 of Set 10 | sittwe
# Processing Record 27 of Set 10 | bouake
# Processing Record 28 of Set 10 | kaele
# Processing Record 29 of Set 10 | djibouti
# Processing Record 30 of Set 10 | kidal
# Processing Record 31 of Set 10 | mont-laurier
# Processing Record 32 of Set 10 | umm kaddadah
# Processing Record 33 of Set 10 | raduzhny
# Processing Record 34 of Set 10 | sisimiut
# Processing Record 35 of Set 10 | tazacorte
# Processing Record 36 of Set 10 | iquique
# Processing Record 37 of Set 10 | kayangel
# Processing Record 38 of Set 10 | shinas
# Processing Record 39 of Set 10 | lycksele
# Processing Record 40 of Set 10 | saldanha
# Processing Record 41 of Set 10 | kanigiri
# Processing Record 42 of Set 10 | itarsi
# Processing Record 43 of Set 10 | buckhannon
# Processing Record 44 of Set 10 | bantogon
# Processing Record 45 of Set 10 | port douglas
# Processing Record 46 of Set 10 | caleta de carquin
# Processing Record 47 of Set 10 | ketchikan
# Processing Record 48 of Set 10 | luderitz
# Processing Record 49 of Set 10 | susuman
# Processing Record 0 of Set 11 | labrador city
# Processing Record 1 of Set 11 | oulad teima
# Processing Record 2 of Set 11 | massena
# Processing Record 3 of Set 11 | 'ohonua
# City not found. Skipping...
# Processing Record 4 of Set 11 | anna regina
# Processing Record 5 of Set 11 | polyarnyy
# Processing Record 6 of Set 11 | cole harbour
# Processing Record 7 of Set 11 | aswan
# Processing Record 8 of Set 11 | lavagna
# Processing Record 9 of Set 11 | kourou
# Processing Record 10 of Set 11 | maun
# Processing Record 11 of Set 11 | richards bay
# Processing Record 12 of Set 11 | andergrove
# Processing Record 13 of Set 11 | trinidad
# Processing Record 14 of Set 11 | kristiansund
# Processing Record 15 of Set 11 | marsa alam
# Processing Record 16 of Set 11 | khanty-mansiysk
# Processing Record 17 of Set 11 | calapan
# Processing Record 18 of Set 11 | staraya russa
# Processing Record 19 of Set 11 | quelimane
# Processing Record 20 of Set 11 | st. john's
# Processing Record 21 of Set 11 | greymouth
# Processing Record 22 of Set 11 | la villa del rosario
# Processing Record 23 of Set 11 | bahcecik
# Processing Record 24 of Set 11 | serhetabat
# Processing Record 25 of Set 11 | pailon
# Processing Record 26 of Set 11 | sirpur
# Processing Record 27 of Set 11 | ishinomaki
# Processing Record 28 of Set 11 | yantarnyy
# Processing Record 29 of Set 11 | palikir - national government center
# Processing Record 30 of Set 11 | inari
# Processing Record 31 of Set 11 | bandarbeyla
# Processing Record 32 of Set 11 | bethanie
# Processing Record 33 of Set 11 | yuki
# Processing Record 34 of Set 11 | nouadhibou
# Processing Record 35 of Set 11 | castillos
# Processing Record 36 of Set 11 | al bawiti
# Processing Record 37 of Set 11 | tosontsengel
# Processing Record 38 of Set 11 | port blair
# Processing Record 39 of Set 11 | rabo de peixe
# Processing Record 40 of Set 11 | strensall
# Processing Record 41 of Set 11 | sinop
# Processing Record 42 of Set 11 | piacabucu
# Processing Record 43 of Set 11 | baro
# Processing Record 44 of Set 11 | visakhapatnam
# Processing Record 45 of Set 11 | olney
# Processing Record 46 of Set 11 | miyazu
# Processing Record 47 of Set 11 | konarka
# Processing Record 48 of Set 11 | ust'-kulom
# Processing Record 49 of Set 11 | kuqa
# Processing Record 0 of Set 12 | wucheng
# Processing Record 1 of Set 12 | pacific grove
# Processing Record 2 of Set 12 | kenora
# Processing Record 3 of Set 12 | kone
# Processing Record 4 of Set 12 | angaur state
# Processing Record 5 of Set 12 | dongola
# Processing Record 6 of Set 12 | ta'izz
# Processing Record 7 of Set 12 | daru
# Processing Record 8 of Set 12 | port hedland
# Processing Record 9 of Set 12 | paramonga
# Processing Record 10 of Set 12 | timimoun
# Processing Record 11 of Set 12 | devils lake
# Processing Record 12 of Set 12 | vastervik
# City not found. Skipping...
# Processing Record 13 of Set 12 | notodden
# Processing Record 14 of Set 12 | hilo
# Processing Record 15 of Set 12 | yagry
# City not found. Skipping...
# Processing Record 16 of Set 12 | aripuana
# Processing Record 17 of Set 12 | villa el carmen
# Processing Record 18 of Set 12 | tarija
# Processing Record 19 of Set 12 | zyrya
# Processing Record 20 of Set 12 | kalaoa
# Processing Record 21 of Set 12 | saudarkrokur
# Processing Record 22 of Set 12 | aspen
# Processing Record 23 of Set 12 | calliope
# Processing Record 24 of Set 12 | sao vicente
# Processing Record 25 of Set 12 | puerto aysen
# Processing Record 26 of Set 12 | rio grande
# Processing Record 27 of Set 12 | manchester
# Processing Record 28 of Set 12 | sao raimundo nonato
# Processing Record 29 of Set 12 | charlottetown
# Processing Record 30 of Set 12 | thung song
# Processing Record 31 of Set 12 | asau
# Processing Record 32 of Set 12 | oranjemund
# Processing Record 33 of Set 12 | brokopondo
# Processing Record 34 of Set 12 | ust'-ilimsk
# Processing Record 35 of Set 12 | al 'alamayn
# City not found. Skipping...
# Processing Record 36 of Set 12 | rukban
# City not found. Skipping...
# Processing Record 37 of Set 12 | whakatane
# Processing Record 38 of Set 12 | tabas
# Processing Record 39 of Set 12 | knoxville
# Processing Record 40 of Set 12 | mikun'
# Processing Record 41 of Set 12 | karratha
# Processing Record 42 of Set 12 | graaff-reinet
# Processing Record 43 of Set 12 | malakal
# Processing Record 44 of Set 12 | khandyga
# Processing Record 45 of Set 12 | broken hill
# Processing Record 46 of Set 12 | yarmouth
# Processing Record 47 of Set 12 | talara
# Processing Record 48 of Set 12 | aracena
# Processing Record 49 of Set 12 | itoman
# Processing Record 0 of Set 13 | berber
# Processing Record 1 of Set 13 | brisas de zicatela
# Processing Record 2 of Set 13 | makoua
# Processing Record 3 of Set 13 | malabar
# Processing Record 4 of Set 13 | bria
# Processing Record 5 of Set 13 | mili
# Processing Record 6 of Set 13 | wenchang
# Processing Record 7 of Set 13 | crane
# Processing Record 8 of Set 13 | galliano
# Processing Record 9 of Set 13 | bowen
# Processing Record 10 of Set 13 | cargados carajos
# City not found. Skipping...
# Processing Record 11 of Set 13 | tual
# Processing Record 12 of Set 13 | iwanai
# Processing Record 13 of Set 13 | devonport
# Processing Record 14 of Set 13 | holdrege
# Processing Record 15 of Set 13 | sepatan
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          589
# Lat           589
# Lng           589
# Max Temp      589
# Humidity      589
# Cloudiness    589
# Wind Speed    589
# Country       589
# Date          589
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          adamstown -25.0660 -130.1015     24.80        75          92
# 1       invercargill -46.4000  168.3500     10.01        88          96
# 2  port-aux-francais -49.3500   70.2167      4.49        97         100
# 3           waitangi -43.9535 -176.5597     11.01        90         100
# 4         isafjordur  66.0755  -23.1240     -0.98        69         100
#
#    Wind Speed Country        Date
# 0        2.02      PN  1737991430
# 1        2.12      NZ  1737991431
# 2       11.03      TF  1737991432
# 3        0.89      NZ  1737991391
# 4        4.12      IS  1737991434

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0                adamstown -25.0660 -130.1015     24.80        75          92
# 1             invercargill -46.4000  168.3500     10.01        88          96
# 2        port-aux-francais -49.3500   70.2167      4.49        97         100
# 3                 waitangi -43.9535 -176.5597     11.01        90         100
# 4               isafjordur  66.0755  -23.1240     -0.98        69         100
#
#          Wind Speed Country        Date
# City_ID
# 0              2.02      PN  1737991430
# 1              2.12      NZ  1737991431
# 2             11.03      TF  1737991432
# 3              0.89      NZ  1737991391
# 4              4.12      IS  1737991434

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Define x and y axis data
x_axis = city_data_df["Lat"]
data = city_data_df["Max Temp"]

# Build scatter plot with additional properties
plt.figure(figsize=(8, 6))
plt.scatter(x_axis, data, marker="o", facecolors="red", edgecolors="black",
            s=100, alpha=0.75)  # Set a fixed size instead of x_axis if needed

# Add graph properties
plt.title("Latitude vs Temperature")
plt.xlabel("Latitude")
plt.ylabel("Temperature (°C)")
plt.grid(True)  # Adds a grid to the background
plt.xticks(rotation=45)  # Rotates x-axis labels for better readability
plt.xlim(min(x_axis) - 5, max(x_axis) + 5)  # Adjust x-axis range
plt.ylim(min(data) - 5, max(data) + 5)  # Adjust y-axis range

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
x_axis = city_data_df["Lat"]
data = city_data_df["Humidity"]

# Build scatter plot with additional properties
plt.figure(figsize=(8, 6))
plt.scatter(x_axis, data, marker="o", facecolors="red", edgecolors="black",
            s=100, alpha=0.75)  # Set a fixed size instead of x_axis if needed

# Add graph properties
plt.title("Latitude vs Humidity")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.grid(True)  # Adds a grid to the background
plt.xticks(rotation=45)  # Rotates x-axis labels for better readability
plt.xlim(min(x_axis) - 5, max(x_axis) + 5)  # Adjust x-axis range
plt.ylim(min(data) - 5, max(data) + 5)  # Adjust y-axis range

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 4
#       2 x_axis = city_data_df["Lat"]
#       3 data = city_data_df["Humidity"]
# ----> 4 city_data_df.loc = city_data["Max Temp">=0]
#       6 # Build scatter plot with additional properties
#       7 plt.figure(figsize=(8, 6))
#
# TypeError: '>=' not supported between instances of 'str' and 'int'

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
x_axis = city_data_df["Lat"]
data = city_data_df["Cloudiness"]
# Build scatter plot with additional properties
plt.figure(figsize=(8, 6))
plt.scatter(x_axis, data, marker="o", facecolors="red", edgecolors="black",
            s=100, alpha=0.75)  # Set a fixed size instead of x_axis if needed

# Add graph properties
plt.title("Latitude vs Cloudiness")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.grid(True)  # Adds a grid to the background
plt.xticks(rotation=45)  # Rotates x-axis labels for better readability
plt.xlim(min(x_axis) - 5, max(x_axis) + 5)  # Adjust x-axis range
plt.ylim(min(data) - 5, max(data) + 5)  # Adjust y-axis range


# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
x_axis = city_data_df["Lat"]
data = city_data_df["Wind Speed"]
# Build scatter plot with additional properties
plt.figure(figsize=(8, 6))
plt.scatter(x_axis, data, marker="o", facecolors="red", edgecolors="black",
            s=100, alpha=0.75)  # Set a fixed size instead of x_axis if needed

# Add graph properties
plt.title("Latitude vs Wind Speed")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.grid(True)  # Adds a grid to the background
plt.xticks(rotation=45)  # Rotates x-axis labels for better readability
plt.xlim(min(x_axis) - 5, max(x_axis) + 5)  # Adjust x-axis range
plt.ylim(min(data) - 5, max(data) + 5)  # Adjust y-axis range


# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
import numpy as np
import matplotlib.pyplot as plt

# Sample data
x = np.array(city_data_df["Lat"])
y = np.array(city_data_df["Max Temp"])

# Calculate slope (m) and intercept (b)
m, b = np.polyfit(x, y, 1)

# Generate regression line values
regression_line = m * x + b

# Plot data points and regression line
plt.scatter(x, y, color="blue", label="Data Points")
plt.plot(x, regression_line, color="red", label=f"y = {m:.2f}x + {b:.2f}")
plt.xlabel("X")
plt.ylabel("Y")
plt.legend()
plt.title("Linear Regression using NumPy")
plt.grid()
plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
import numpy as np
import matplotlib.pyplot as plt
northern_hemi_df = city_data_df.loc[city_data_df["Lat"] >= 0]
northern_hemi_df
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 4         isafjordur  66.0755  -23.1240     -0.98        69         100
# 7             albany  42.6001  -73.9662     -0.96        58           3
# 8            selfoss  63.9331  -20.9971     -4.42        84         100
# 10             vadso  70.0744   29.7487     -3.91        93          75
# 11       vilyuchinsk  52.9306  158.4028    -11.85        80         100
# ...              ...      ...       ...       ...       ...         ...
# 580         wenchang  30.9040  118.4887      0.21        56           0
# 581            crane  31.3974 -102.3501      3.55        56          66
# 582         galliano  29.4422  -90.2992     19.00        82         100
# 585           iwanai  42.9744  140.5089     -3.20        95          77
# 587         holdrege  40.4403  -99.3698     -4.05        63           0
#
#          Wind Speed Country        Date
# City_ID
# 4              4.12      IS  1737991434
# 7              4.27      US  1737991395
# 8              3.39      IS  1737991438
# 10             1.03      NO  1737991441
# 11             2.93      RU  1737991442
# ...             ...     ...         ...
# 580            2.40      CN  1737992639
# 581            5.97      US  1737992641
# 582            2.06      US  1737992642
# 585            2.24      JP  1737992646
# 587            5.14      US  1737992648
#
# [412 rows x 9 columns]

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
import numpy as np
import matplotlib.pyplot as plt
southern_hemi_df = city_data_df.loc[city_data_df["Lat"] < 0]
southern_hemi_df
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0                adamstown -25.0660 -130.1015     24.80        75          92
# 1             invercargill -46.4000  168.3500     10.01        88          96
# 2        port-aux-francais -49.3500   70.2167      4.49        97         100
# 3                 waitangi -43.9535 -176.5597     11.01        90         100
# 5           margaret river -33.9500  115.0667     15.94        74           0
# ...                    ...      ...       ...       ...       ...         ...
# 577                malabar -33.9667  151.2500     23.40        88         100
# 583                  bowen -20.0167  148.2333     25.69        87         100
# 584                   tual  -5.6667  132.7500     28.10        78          87
# 586              devonport -41.1667  146.3500     14.73        94           4
# 588                sepatan  -6.1189  106.5750     26.01        88          20
#
#          Wind Speed Country        Date
# City_ID
# 0              2.02      PN  1737991430
# 1              2.12      NZ  1737991431
# 2             11.03      TF  1737991432
# 3              0.89      NZ  1737991391
# 5              6.40      AU  1737991435
# ...             ...     ...         ...
# 577            3.60      AU  1737992636
# 583            6.02      AU  1737992643
# 584            7.94      ID  1737992645
# 586            5.16      AU  1737992647
# 588            4.63      ID  1737992649
#
# [177 rows x 9 columns]

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x = np.array(northern_hemi_df["Lat"])
y = np.array(northern_hemi_df["Max Temp"])

# Calculate slope (m) and intercept (b)
m, b = np.polyfit(x, y, 1)

# Generate regression line values
regression_line = m * x + b

# Plot data points and regression line
plt.scatter(x, y, color="blue", label="Data Points")
plt.plot(x, regression_line, color="red", label=f"y = {m:.2f}x + {b:.2f}")
plt.xlabel("X")
plt.ylabel("Y")
plt.legend()
plt.title("Linear Regression using NumPy")
plt.grid()
plt.show()
northern_hemi_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 4         isafjordur  66.0755  -23.1240     -0.98        69         100
# 7             albany  42.6001  -73.9662     -0.96        58           3
# 8            selfoss  63.9331  -20.9971     -4.42        84         100
# 10             vadso  70.0744   29.7487     -3.91        93          75
# 11       vilyuchinsk  52.9306  158.4028    -11.85        80         100
#
#          Wind Speed Country        Date
# City_ID
# 4              4.12      IS  1737991434
# 7              4.27      US  1737991395
# 8              3.39      IS  1737991438
# 10             1.03      NO  1737991441
# 11             2.93      RU  1737991442

# %%
# Linear regression on Southern Hemisphere

# Sample data
x = np.array(southern_hemi_df["Lat"])
y = np.array(southern_hemi_df["Max Temp"])

# Calculate slope (m) and intercept (b)
m, b = np.polyfit(x, y, 1)

# Generate regression line values
regression_line = m * x + b

# Plot data points and regression line
plt.scatter(x, y, color="blue", label="Data Points")
plt.plot(x, regression_line, color="red", label=f"y = {m:.2f}x + {b:.2f}")
plt.xlabel("X")
plt.ylabel("Y")
plt.legend()
plt.title("Linear Regression using NumPy")
plt.grid()
plt.show()
northern_hemi_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 4         isafjordur  66.0755  -23.1240     -0.98        69         100
# 7             albany  42.6001  -73.9662     -0.96        58           3
# 8            selfoss  63.9331  -20.9971     -4.42        84         100
# 10             vadso  70.0744   29.7487     -3.91        93          75
# 11       vilyuchinsk  52.9306  158.4028    -11.85        80         100
#
#          Wind Speed Country        Date
# City_ID
# 4              4.12      IS  1737991434
# 7              4.27      US  1737991395
# 8              3.39      IS  1737991438
# 10             1.03      NO  1737991441
# 11             2.93      RU  1737991442

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# Sample data
x = np.array(northern_hemi_df["Lat"])
y = np.array(northern_hemi_df["Humidity"])

# Calculate slope (m) and intercept (b)
m, b = np.polyfit(x, y, 1)

# Generate regression line values
regression_line = m * x + b

# Plot data points and regression line
plt.scatter(x, y, color="blue", label="Data Points")
plt.plot(x, regression_line, color="red", label=f"y = {m:.2f}x + {b:.2f}")
plt.xlabel("X")
plt.ylabel("Y")
plt.legend()
plt.title("Linear Regression using NumPy")
plt.grid()
plt.show()
northern_hemi_df.head()
# Display sample data
southern_hemi_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0                adamstown -25.0660 -130.1015     24.80        75          92
# 1             invercargill -46.4000  168.3500     10.01        88          96
# 2        port-aux-francais -49.3500   70.2167      4.49        97         100
# 3                 waitangi -43.9535 -176.5597     11.01        90         100
# 5           margaret river -33.9500  115.0667     15.94        74           0
#
#          Wind Speed Country        Date
# City_ID
# 0              2.02      PN  1737991430
# 1              2.12      NZ  1737991431
# 2             11.03      TF  1737991432
# 3              0.89      NZ  1737991391
# 5              6.40      AU  1737991435

# %%
# NortheSouthern Hemisphere
# Sample data
x = np.array(southern_hemi_df["Lat"])
y = np.array(southern_hemi_df["Humidity"])

# Calculate slope (m) and intercept (b)
m, b = np.polyfit(x, y, 1)

# Generate regression line values
regression_line = m * x + b

# Plot data points and regression line
plt.scatter(x, y, color="blue", label="Data Points")
plt.plot(x, regression_line, color="red", label=f"y = {m:.2f}x + {b:.2f}")
plt.xlabel("X")
plt.ylabel("Y")
plt.legend()
plt.title("Linear Regression using NumPy")
plt.grid()
plt.show()
northern_hemi_df.head()
# Display sample data
southern_hemi_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0                adamstown -25.0660 -130.1015     24.80        75          92
# 1             invercargill -46.4000  168.3500     10.01        88          96
# 2        port-aux-francais -49.3500   70.2167      4.49        97         100
# 3                 waitangi -43.9535 -176.5597     11.01        90         100
# 5           margaret river -33.9500  115.0667     15.94        74           0
#
#          Wind Speed Country        Date
# City_ID
# 0              2.02      PN  1737991430
# 1              2.12      NZ  1737991431
# 2             11.03      TF  1737991432
# 3              0.89      NZ  1737991391
# 5              6.40      AU  1737991435

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# Sample data
x = np.array(northern_hemi_df["Lat"])
y = np.array(northern_hemi_df["Cloudiness"])

# Calculate slope (m) and intercept (b)
m, b = np.polyfit(x, y, 1)

# Generate regression line values
regression_line = m * x + b

# Plot data points and regression line
plt.scatter(x, y, color="blue", label="Data Points")
plt.plot(x, regression_line, color="red", label=f"y = {m:.2f}x + {b:.2f}")
plt.xlabel("X")
plt.ylabel("Y")
plt.legend()
plt.title("Linear Regression using NumPy")
plt.grid()
plt.show()
northern_hemi_df.head()
# Display sample data
southern_hemi_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0                adamstown -25.0660 -130.1015     24.80        75          92
# 1             invercargill -46.4000  168.3500     10.01        88          96
# 2        port-aux-francais -49.3500   70.2167      4.49        97         100
# 3                 waitangi -43.9535 -176.5597     11.01        90         100
# 5           margaret river -33.9500  115.0667     15.94        74           0
#
#          Wind Speed Country        Date
# City_ID
# 0              2.02      PN  1737991430
# 1              2.12      NZ  1737991431
# 2             11.03      TF  1737991432
# 3              0.89      NZ  1737991391
# 5              6.40      AU  1737991435

# %%
# Southern Hemisphere
# Sample data
x = np.array(southern_hemi_df["Lat"])
y = np.array(southern_hemi_df["Cloudiness"])

# Calculate slope (m) and intercept (b)
m, b = np.polyfit(x, y, 1)

# Generate regression line values
regression_line = m * x + b

# Plot data points and regression line
plt.scatter(x, y, color="blue", label="Data Points")
plt.plot(x, regression_line, color="red", label=f"y = {m:.2f}x + {b:.2f}")
plt.xlabel("X")
plt.ylabel("Y")
plt.legend()
plt.title("Linear Regression using NumPy")
plt.grid()
plt.show()
northern_hemi_df.head()
# Display sample data
southern_hemi_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0                adamstown -25.0660 -130.1015     24.80        75          92
# 1             invercargill -46.4000  168.3500     10.01        88          96
# 2        port-aux-francais -49.3500   70.2167      4.49        97         100
# 3                 waitangi -43.9535 -176.5597     11.01        90         100
# 5           margaret river -33.9500  115.0667     15.94        74           0
#
#          Wind Speed Country        Date
# City_ID
# 0              2.02      PN  1737991430
# 1              2.12      NZ  1737991431
# 2             11.03      TF  1737991432
# 3              0.89      NZ  1737991391
# 5              6.40      AU  1737991435

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# Sample data
x = np.array(northern_hemi_df["Lat"])
y = np.array(northern_hemi_df["Wind Speed"])

# Calculate slope (m) and intercept (b)
m, b = np.polyfit(x, y, 1)

# Generate regression line values
regression_line = m * x + b

# Plot data points and regression line
plt.scatter(x, y, color="blue", label="Data Points")
plt.plot(x, regression_line, color="red", label=f"y = {m:.2f}x + {b:.2f}")
plt.xlabel("X")
plt.ylabel("Y")
plt.legend()
plt.title("Linear Regression using NumPy")
plt.grid()
plt.show()
northern_hemi_df.head()
# Display sample data
southern_hemi_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0                adamstown -25.0660 -130.1015     24.80        75          92
# 1             invercargill -46.4000  168.3500     10.01        88          96
# 2        port-aux-francais -49.3500   70.2167      4.49        97         100
# 3                 waitangi -43.9535 -176.5597     11.01        90         100
# 5           margaret river -33.9500  115.0667     15.94        74           0
#
#          Wind Speed Country        Date
# City_ID
# 0              2.02      PN  1737991430
# 1              2.12      NZ  1737991431
# 2             11.03      TF  1737991432
# 3              0.89      NZ  1737991391
# 5              6.40      AU  1737991435

# %%
# Southern Hemisphere
# Northern Hemisphere
# Sample data
x = np.array(southern_hemi_df["Lat"])
y = np.array(southern_hemi_df["Wind Speed"])

# Calculate slope (m) and intercept (b)
m, b = np.polyfit(x, y, 1)

# Generate regression line values
regression_line = m * x + b

# Plot data points and regression line
plt.scatter(x, y, color="blue", label="Data Points")
plt.plot(x, regression_line, color="red", label=f"y = {m:.2f}x + {b:.2f}")
plt.xlabel("X")
plt.ylabel("Y")
plt.legend()
plt.title("Linear Regression using NumPy")
plt.grid()
plt.show()
northern_hemi_df.head()
# Display sample data
southern_hemi_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0                adamstown -25.0660 -130.1015     24.80        75          92
# 1             invercargill -46.4000  168.3500     10.01        88          96
# 2        port-aux-francais -49.3500   70.2167      4.49        97         100
# 3                 waitangi -43.9535 -176.5597     11.01        90         100
# 5           margaret river -33.9500  115.0667     15.94        74           0
#
#          Wind Speed Country        Date
# City_ID
# 0              2.02      PN  1737991430
# 1              2.12      NZ  1737991431
# 2             11.03      TF  1737991432
# 3              0.89      NZ  1737991391
# 5              6.40      AU  1737991435

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
